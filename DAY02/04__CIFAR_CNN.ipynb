# %% [markdown]
# - [1] 모듈 로딩 <hr>

# %%
### ===> Module Import
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms, datasets

# %%
### ===> 딥러닝 모델을 설계할 때 활용하는 장비 확인
if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')
    
print('Using PyTorch version:', torch.__version__, ' Device:', DEVICE)
# Out:
# Using PyTorch version: 2.2.1+cpu  Device: cpu

# %% [markdown]
# - [2] 데이터 준비 <hr>

# %%
### ===>  데이터 추출 관련 변수
BATCH_SIZE = 32
EPOCHS = 10

# %%
### ===> CIFAR10 데이터 다운로드 (Train set, Test set 분리하기)
train_dataset = datasets.CIFAR10(root = "../data/CIFAR_10",
                                  train = True,
                                  download = True,
                                  transform = transforms.ToTensor())

test_dataset = datasets.CIFAR10(root = "../data/CIFAR_10",
                                train = False,
                                transform = transforms.ToTensor())

train_loader = torch.utils.data.DataLoader(dataset = train_dataset,
                                            batch_size = BATCH_SIZE,
                                            shuffle = True)

test_loader = torch.utils.data.DataLoader(dataset = test_dataset,
                                          batch_size = BATCH_SIZE,
                                          shuffle = False)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ../data/CIFAR_10\cifar-10-python.tar.gz
# 100.0%
# Extracting ../data/CIFAR_10\cifar-10-python.tar.gz to ../data/CIFAR_10

# %%
### ===>  데이터 확인하기 (1)
### X_train : torch.Size([32,3,32,32]) [배치사이즈, 채널, 높이, 너비]
### Y_train : torch.Size([32]) [배치사이즈] 즉, 32개 이미지에 대한 라벨

for (X_train, y_train) in train_loader:
    print('X_train:', X_train.size(), 'type:', X_train.type())
    print('y_train:', y_train.size(), 'type:', y_train.type())
    break
# Out:
# X_train: torch.Size([32, 3, 32, 32]) type: torch.FloatTensor
# y_train: torch.Size([32]) type: torch.LongTensor

# %%
### ===>  데이터 확인하기 (2) 
pltsize = 1
plt.figure(figsize=(10 * pltsize, pltsize))

for i in range(10):
    plt.subplot(1, 10, i + 1)
    plt.axis('off')
    plt.imshow(np.transpose(X_train[i], (1, 2, 0)))
    plt.title('Class: ' + str(y_train[i].item()))

# %% [markdown]
# - [3] 모델 설계 <hr>

# %%
### ===>  Convolutional Neural Network (CNN) 모델 설계하기
### X_train : torch.Size([32,3,32,32]) [배치사이즈, 채널, 높이, 너비]
### Y_train : torch.Size([32]) [배치사이즈] 즉, 32개 이미지에 대한 라벨

class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(in_channels = 3, out_channels = 8, kernel_size = 3, padding = 1)
        self.conv2 = nn.Conv2d(in_channels = 8, out_channels = 16, kernel_size = 3, padding = 1)
        self.pool = nn.MaxPool2d(kernel_size = 2, stride = 2)
        self.fc1 = nn.Linear(8 * 8 * 16, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 10)
        
    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.pool(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = self.pool(x)
        
        x = x.view(-1, 8 * 8 * 16)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.fc3(x)
        x = F.log_softmax(x)
        return x

# %% [markdown]
# - [4] 학습 준비 <hr>

# %%
### ===> Optimizer, Objective Function 설정
model = CNN().to(DEVICE)

optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)

criterion = nn.CrossEntropyLoss()

# %%
from torchviz import make_dot

#x=torch.randn(1,3,32,32).to(DEVICE)
#y=model(x)

make_dot(model(X_train),params=dict(model.named_parameters()))
# Out:
# C:\Users\mathn\AppData\Local\Temp\ipykernel_26528\495300245.py:28: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = F.log_softmax(x)

# %%
### ===> CNN 모델 학습을 진행하며 학습 데이터에 대한 모델 성능을 확인하는 함수 정의
def train(epoch, model, train_loader, optimizer, log_interval):
    model.train()
    for batch_idx, (image, label) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        optimizer.zero_grad()
        output = model(image)
        loss = criterion(output, label)
        loss.backward()
        optimizer.step()

        if batch_idx % log_interval == 0:
            print(f"Train Epoch: {epoch} [{batch_idx}]\tTrain Loss: {loss.item():.6f}")

# %%
### ===> 학습되는 과정 속에서 검증 데이터에 대한 모델 성능을 확인하는 함수 정의
def evaluate(model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0

    with torch.no_grad():
        for image, label in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            
            output = model(image)
            test_loss += criterion(output, label).item()
            prediction = output.max(1, keepdim = True)[1]
            correct += prediction.eq(label.view_as(prediction)).sum().item()
    
    test_loss /= len(test_loader.dataset)
    test_accuracy = 100. * correct / len(test_loader.dataset)
    return test_loss, test_accuracy

# %% [markdown]
# - [5] 학습진행 <hr>

# %%
### ===> CNN 학습 실행하며 Train, Test set의 Loss 및 Test set Accuracy 확인
for epoch in range(1, EPOCHS + 1):
    
    train(epoch, model, train_loader, optimizer, log_interval = 200)
    test_loss, test_accuracy = evaluate(model, test_loader)
    
    print(f"\n[EPOCH: {epoch}], \tTest Loss: {test_loss:.4f}, \tTest Accuracy: {test_accuracy:.2f} % \n")
# Out:
# C:\Users\mathn\AppData\Local\Temp\ipykernel_26528\495300245.py:28: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = F.log_softmax(x)
# Train Epoch: 1 [0]	Train Loss: 2.335274
# Train Epoch: 1 [200]	Train Loss: 2.043832
# Train Epoch: 1 [400]	Train Loss: 2.013060
# Train Epoch: 1 [600]	Train Loss: 1.603888
# Train Epoch: 1 [800]	Train Loss: 1.596516
# Train Epoch: 1 [1000]	Train Loss: 1.447770
# Train Epoch: 1 [1200]	Train Loss: 1.587064
# Train Epoch: 1 [1400]	Train Loss: 1.374589
#
# [EPOCH: 1], 	Test Loss: 0.0459, 	Test Accuracy: 46.85 %
#
# Train Epoch: 2 [0]	Train Loss: 1.239936
# Train Epoch: 2 [200]	Train Loss: 1.499764
# Train Epoch: 2 [400]	Train Loss: 1.622422
# Train Epoch: 2 [600]	Train Loss: 1.394702
# Train Epoch: 2 [800]	Train Loss: 1.411709
# Train Epoch: 2 [1000]	Train Loss: 1.564427
# Train Epoch: 2 [1200]	Train Loss: 1.353793
# Train Epoch: 2 [1400]	Train Loss: 1.374298
#
# [EPOCH: 2], 	Test Loss: 0.0428, 	Test Accuracy: 50.53 %
#
# Train Epoch: 3 [0]	Train Loss: 1.209878
# Train Epoch: 3 [200]	Train Loss: 1.517881
# Train Epoch: 3 [400]	Train Loss: 1.280127
# Train Epoch: 3 [600]	Train Loss: 1.321527
# Train Epoch: 3 [800]	Train Loss: 1.623076
# Train Epoch: 3 [1000]	Train Loss: 1.132029
# Train Epoch: 3 [1200]	Train Loss: 1.353849
# Train Epoch: 3 [1400]	Train Loss: 1.292852
#
# [EPOCH: 3], 	Test Loss: 0.0404, 	Test Accuracy: 53.22 %
#
# Train Epoch: 4 [0]	Train Loss: 1.374353
# Train Epoch: 4 [200]	Train Loss: 1.473438
# Train Epoch: 4 [400]	Train Loss: 1.246224
# Train Epoch: 4 [600]	Train Loss: 1.459239
# Train Epoch: 4 [800]	Train Loss: 1.727561
# Train Epoch: 4 [1000]	Train Loss: 0.873684
# Train Epoch: 4 [1200]	Train Loss: 1.267232
# Train Epoch: 4 [1400]	Train Loss: 1.355900
#
# [EPOCH: 4], 	Test Loss: 0.0380, 	Test Accuracy: 56.00 %
#
# Train Epoch: 5 [0]	Train Loss: 1.249865
# Train Epoch: 5 [200]	Train Loss: 1.196636
# Train Epoch: 5 [400]	Train Loss: 1.012579
# Train Epoch: 5 [600]	Train Loss: 1.049150
# Train Epoch: 5 [800]	Train Loss: 1.248181
# Train Epoch: 5 [1000]	Train Loss: 1.461688
# Train Epoch: 5 [1200]	Train Loss: 1.188146
# Train Epoch: 5 [1400]	Train Loss: 1.556442
#
# [EPOCH: 5], 	Test Loss: 0.0380, 	Test Accuracy: 56.42 %
#
# Train Epoch: 6 [0]	Train Loss: 1.113246
# Train Epoch: 6 [200]	Train Loss: 1.430640
# Train Epoch: 6 [400]	Train Loss: 1.563058
# Train Epoch: 6 [600]	Train Loss: 0.791499
# Train Epoch: 6 [800]	Train Loss: 1.401612
# Train Epoch: 6 [1000]	Train Loss: 1.282870
# Train Epoch: 6 [1200]	Train Loss: 0.890214
# Train Epoch: 6 [1400]	Train Loss: 1.205351
#
# [EPOCH: 6], 	Test Loss: 0.0371, 	Test Accuracy: 57.61 %
#
# Train Epoch: 7 [0]	Train Loss: 0.983244
# Train Epoch: 7 [200]	Train Loss: 1.093360
# Train Epoch: 7 [400]	Train Loss: 1.051455
# Train Epoch: 7 [600]	Train Loss: 1.101439
# Train Epoch: 7 [800]	Train Loss: 0.861776
# Train Epoch: 7 [1000]	Train Loss: 1.401140
# Train Epoch: 7 [1200]	Train Loss: 0.925347
# Train Epoch: 7 [1400]	Train Loss: 0.954727
#
# [EPOCH: 7], 	Test Loss: 0.0350, 	Test Accuracy: 60.81 %
#
# Train Epoch: 8 [0]	Train Loss: 1.135831
# Train Epoch: 8 [200]	Train Loss: 1.247052
# Train Epoch: 8 [400]	Train Loss: 0.821769
# Train Epoch: 8 [600]	Train Loss: 1.120188
# Train Epoch: 8 [800]	Train Loss: 1.367144
# Train Epoch: 8 [1000]	Train Loss: 1.275983
# Train Epoch: 8 [1200]	Train Loss: 1.571416
# Train Epoch: 8 [1400]	Train Loss: 0.926637
#
# [EPOCH: 8], 	Test Loss: 0.0355, 	Test Accuracy: 59.35 %
#
# Train Epoch: 9 [0]	Train Loss: 0.846319
# Train Epoch: 9 [200]	Train Loss: 0.841991
# Train Epoch: 9 [400]	Train Loss: 1.233416
# Train Epoch: 9 [600]	Train Loss: 1.098445
# Train Epoch: 9 [800]	Train Loss: 1.057391
# Train Epoch: 9 [1000]	Train Loss: 0.894464
# Train Epoch: 9 [1200]	Train Loss: 1.222087
# Train Epoch: 9 [1400]	Train Loss: 1.259336
#
# [EPOCH: 9], 	Test Loss: 0.0340, 	Test Accuracy: 61.80 %
#
# Train Epoch: 10 [0]	Train Loss: 1.242095
# Train Epoch: 10 [200]	Train Loss: 0.911563
# Train Epoch: 10 [400]	Train Loss: 1.030880
# Train Epoch: 10 [600]	Train Loss: 0.774153
# Train Epoch: 10 [800]	Train Loss: 0.751966
# Train Epoch: 10 [1000]	Train Loss: 0.846281
# Train Epoch: 10 [1200]	Train Loss: 1.267523
# Train Epoch: 10 [1400]	Train Loss: 1.005672
#
# [EPOCH: 10], 	Test Loss: 0.0336, 	Test Accuracy: 62.19 %
